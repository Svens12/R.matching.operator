# %%
x<-c(10,45,30,50,35,40,80)

# %%
35 %in% x
# Out:
# [1] TRUE

# %%
x<-c(10,45,30,50,35,40,80)
37 %in% x
# Out:
# [1] FALSE

# %%
x<-c(10,45,30,50,35,40,80)
y<-30
y %in% x
# Out:
# [1] TRUE

# %%
x<-c(10,45,30,50,35,40,80)
y<-c(30,35)
y %in% x
# Out:
# [1] TRUE TRUE

# %%
x<-c(10,45,30,50,35,40,80)
y<-c(30,37,35)
y %in% x
# Out:
# [1]  TRUE FALSE  TRUE
